# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("../data/data.csv")
df.describe()
# Out:
#              valence           year   acousticness   danceability  \
# count  170653.000000  170653.000000  170653.000000  170653.000000
# mean        0.528587    1976.787241       0.502115       0.537396
# std         0.263171      25.917853       0.376032       0.176138
# min         0.000000    1921.000000       0.000000       0.000000
# 25%         0.317000    1956.000000       0.102000       0.415000
# 50%         0.540000    1977.000000       0.516000       0.548000
# 75%         0.747000    1999.000000       0.893000       0.668000
# max         1.000000    2020.000000       0.996000       0.988000
#
#         duration_ms         energy       explicit  instrumentalness  \
# count  1.706530e+05  170653.000000  170653.000000     170653.000000
# mean   2.309483e+05       0.482389       0.084575          0.167010
# std    1.261184e+05       0.267646       0.278249          0.313475
# min    5.108000e+03       0.000000       0.000000          0.000000
# ...

# %%
df.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# ...

# %%
df[df['artists'].apply(lambda x: 'SHY Martin' in x)]
#add ability to add more songs to database based on lookup
# Out:
#        valence  year  acousticness                       artists  \
# 56499    0.188  2016        0.0225  ['Mike Perry', 'SHY Martin']
#
#        danceability  duration_ms  energy  explicit                      id  \
# 56499         0.632       183414   0.575         0  2CPqh63wRVscbceKcPxwvv
#
#        instrumentalness  key  liveness  loudness  mode  \
# 56499          0.000002    5     0.104    -6.478     1
#
#                                name  popularity release_date  speechiness  \
# 56499  The Ocean (feat. Shy Martin)          73   2016-04-15        0.029
#
#         tempo
# 56499  90.037

# %% [markdown]
# Scaling the data

# %%
from sklearn.preprocessing import StandardScaler

#scale the numerical features we care about so that no feature has more weight than another
numerical_features = ['valence', 'acousticness', 'danceability', 'energy', 
                      'instrumentalness', 'liveness', 'speechiness', 'tempo']

std_scaler= StandardScaler()
X_scaled = std_scaler.fit_transform(df[numerical_features])
X_scaled.shape
# Out:
# (170653, 8)

# %% [markdown]
# K Means Algorithm and Elbow Method

# %%
from sklearn.cluster import KMeans
inertia = [] 
for k in range(1,11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_) #this is the sum of costs within clusters

# %%
plt.plot(range(1,11), inertia, marker = 'o')
plt.xlabel("Number of K Clusters")
plt.ylabel("WCSS/Inertia")
plt.title('Elbow Method')
# Out:
# Text(0.5, 1.0, 'Elbow Method')

# %% [markdown]
# From here, we see that K=5 is the sweet spot. However, let's see if PCA dimensionality reduction can improve clustering.

# %%
from sklearn.decomposition import PCA
import numpy as np


pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# Plot explained variance ratio based on pca components
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance')
plt.title('PCA Explained Variance')
plt.show()

# %%
pca = PCA(n_components=6)
X_reduced = pca.fit_transform(X_scaled)

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

wcss = [] 

for k in range(1, 11):  
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_reduced)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('WCSS')
plt.title('Elbow Method for Optimal k')
plt.show()

# %% [markdown]
# Seems like PCA, and then clustering, improved our WCSS at K=5.

# %%
kmeans = KMeans(n_clusters = 5, random_state=42)
df['Cluster'] = kmeans.fit_predict(X_reduced)
df['Cluster'].value_counts()
# Out:
# Cluster
# 0    55331
# 3    46970
# 1    37410
# 4    25064
# 2     5878
# Name: count, dtype: int64

# %% [markdown]
# Let's see how our reduced dimension data looks as clusters

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(X_reduced)

plt.figure(figsize=(10,8))
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=df["Cluster"], cmap="viridis")
plt.title("K-Means Clusters")
plt.show()

# %% [markdown]
# Recommendation function

# %%
#put the Principal components in the original dataframe
for i in range(X_reduced.shape[1]): 
    df[f'PC{i+1}'] = X_reduced[:, i]
df.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

def recommend_songs(song, df, num_rec=5):
    # Find what cluster input song belongs to and extract the cluster songs
    is_present_in_col = df['name'].isin([song]).any()
    if is_present_in_col == False:
        return "Error: Song not Found"
    song_cluster = df[df["name"] == song]["Cluster"].values[0]
    similar_songs = df[df["Cluster"] == song_cluster]

    # Extract numerical features (PCA components) from the same cluster
    pca_features = [f'PC{i+1}' for i in range(X_reduced.shape[1])]
    cluster_features = similar_songs[pca_features].values

    # Get the feature vector of the input song
    song_index = similar_songs[similar_songs['name'] == song].index[0]
    song_vector = similar_songs.loc[song_index, pca_features].values.reshape(1, -1)

    # Compute pairwise similarity (1xN) instead of the full NxN matrix
    similarity_scores = cosine_similarity(song_vector, cluster_features)[0]

    # Get the indices of the most similar songs (excluding the input song)
    top_songs_indices = np.argsort(similarity_scores)[::-1][1:num_rec+1]

    # Retrieve recommended songs
    recommendations = similar_songs.iloc[top_songs_indices][["name", "year", "artists"]]

    similar_songs["Similarity"] = similarity_scores  # Add similarity scores to dataframe
    print(similar_songs[["name", "Similarity"]].sort_values(by="Similarity", ascending=False))  # Show sorted similarities

    return recommendations

# %%
input_song =  "Shape of You"
recommended_songs = recommend_songs(input_song, df)
# Out:
#                                 name  Similarity
# 19074                   Shape of You    1.000000
# 74616                   Shape of You    1.000000
# 15678                Mis Tres Viejas    0.997045
# 121539            El Mono De Alambre    0.996988
# 53880                   Métele Sazón    0.996268
# ...                              ...         ...
# 19513   you should see me in a crown   -0.153131
# 4896                      Cubana Bop   -0.158978
# 160943                  All I Can Do   -0.189736
# 97582            Lulu's Back In Town   -0.208270
# 31318         Two Suns in the Sunset   -0.214909
#
# [55331 rows x 2 columns]
# C:\Users\18183\AppData\Local\Temp\ipykernel_18788\1973596199.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.to_csv('clustered_df.csv')
